# %%
import pandas as pd
import geopandas as gpd
import os

pd.set_option('display.max_rows',2000)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
file_path = os.path.join('..', '[DATA] Ports Files', 'Standardized', 'Passenger', f'2023 - Passenger.csv')
df = pd.read_csv(file_path)
df
# Out:
#                     Region                                          PMO                                            Port                                 Pier/Terminal  January | Total  January | Disembarked  January | Embarked  January | Cruise Ships  February | Total  February | Disembarked  February | Embarked  February | Cruise Ships  March | Total  March | Disembarked  March | Embarked  March | Cruise Ships  1st Quarter | Total  1st Quarter | Disembarked  1st Quarter | Embarked  1st Quarter | Cruise Ships  April | Total  April | Disembarked  April | Embarked  April | Cruise Ships  May | Total  May | Disembarked  May | Embarked  May | Cruise Ships  June | Total  June | Disembarked  June | Embarked  June | Cruise Ships  2nd Quarter | Total  2nd Quarter | Disembarked  2nd Quarter | Embarked  2nd Quarter | Cruise Ships  July | Total  July | Disembarked  July | Embarked  July | Cruise Ships  August | Total  August | Disembarked  August | Embarked  August | Cruise Ships  \
# ...

# %%
shp_path = os.path.join('..', 'philippines-psgc-shapefiles', 'philippines-psgc-shapefiles', 'data', '2023', 'Municities', 'phl_admbnda_adm3_psa_namria_20231106.shp')
map_df = gpd.read_file(shp_path)

# %%
data = map_df[['ADM3_EN', 'ADM2_EN', 'ADM1_EN']]
data.ADM1_EN.value_counts()
# Out:
# ADM1_EN
# Region VIII (Eastern Visayas)                              143
# Region IV-A (Calabarzon)                                   142
# Region VI (Western Visayas)                                133
# Region VII (Central Visayas)                               132
# Region III (Central Luzon)                                 130
# Bangsamoro Autonomous Region In Muslim Mindanao (BARMM)    127
# Region I (Ilocos Region)                                   125
# Region V (Bicol Region)                                    114
# Region II (Cagayan Valley)                                  93
# Region X (Northern Mindanao)                                93
# Cordillera Administrative Region (CAR)                      77
# Region XIII (Caraga)                                        73
# Mimaropa Region                                             73
# Region IX (Zamboanga Peninsula)                             72
# Region XI (Davao Region)                                    49
# ...

# %%
data[data['ADM3_EN'] == "Plaridel"]
# Out:
#        ADM3_EN             ADM2_EN                       ADM1_EN
# 246   Plaridel             Bulacan    Region III (Central Luzon)
# 462   Plaridel              Quezon      Region IV-A (Calabarzon)
# 1145  Plaridel  Misamis Occidental  Region X (Northern Mindanao)

# %%
data.ADM1_EN.value_counts()

# %%
df['Pier/Terminal'].nunique()

# %%
df[['Region', 'PMO', 'Port', 'Pier/Terminal']]
# Out:
#                     Region                                          PMO                                            Port                                 Pier/Terminal
# 0    Manila/Northern Luzon                                          NaN                                             NaN                                           NaN
# 1    Manila/Northern Luzon                                PMO NCR South                                             NaN                                           NaN
# 2    Manila/Northern Luzon                                PMO NCR South                                 BP South Harbor                                           NaN
# 3    Manila/Northern Luzon                                PMO NCR South                                 BP South Harbor                                        Pier 3
# ...

# %%
data[['ADM1_EN', 'ADM2_EN', 'ADM3_EN']]
# Out:
#                                                       ADM1_EN                              ADM2_EN                                          ADM3_EN
# 0                                    Region I (Ilocos Region)                         Ilocos Norte                                            Adams
# 1                                    Region I (Ilocos Region)                         Ilocos Norte                                          Bacarra
# 2                                    Region I (Ilocos Region)                         Ilocos Norte                                            Badoc
# 3                                    Region I (Ilocos Region)                         Ilocos Norte                                           Bangui
# 4                                    Region I (Ilocos Region)                         Ilocos Norte                                    City of Batac
# ...
